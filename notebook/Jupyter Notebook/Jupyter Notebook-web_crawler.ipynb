# %% [markdown]
# 利用 pip freeze 可以確認當前安裝了那些套件，如果想要更新套件，就輸入<br>
# pip install --update 套件名稱
#
# 下列指令可以列出目前已安裝的所有套件：<br>
# pip freeze
#
# 建議安裝 Anaconda，如有安裝 Anaconda 只需安裝以下套件<br>
# $ pip install selenium tldextract Pillow

# %% [markdown]
# ***
# 在終端中輸入：<br>
# pip install pyinstaller
#
# easy_install pip<br>
# pip install BeautifulSoup4
#
# install pip:<br>
# python -m pip install --upgrade pip<br>
# pip install requests<br>
# pip install fake_useragent<br>
# pip install selenium
#
# import urllib2<br>
# from bs4 import BeautifulSoup<br>
# <<urllib2 在 python3.x 中被改为urllib.request>>
# ***
# 使用Python爬蟲所需要以下的lib 安裝<br>
# pip install beautifulsoup4<br>
# pip install lxml<br>
# pip install requests:額外安裝，Python 資料處理所需套件<br>
# pip install Pandas:Pandas 資料處理好幫手Pandas，Pandas可以用來更方便處理資料

# %% [markdown]
# ~~~
# # 第一支爬蟲程式
#
# # import 套件
# import requests
# from bs4 import BeautifulSoup
# # 用 requests 抓取網頁並存在 response
# response =requests.get("https://jimmy15923.github.io/example_page")
# # 用 BS4 解析 HTML 並把結果回傳 soup
# soup = BeautifulSoup(response.text,"lxml")
# # 印出 h1 標籤
# print(soup.find("h1"))
#
# # 目標網頁的 HTML 文字
# response.text
# # HTTP 狀態碼
# response.status_code
# # 判斷編碼
# response.encoding
#
# BeautifulSoup
# # 請輸入以下的 codes 並 print 出結果
# print(soup.find("h1")
# print(soup.h1)
# print(soup.html.h1)
# print(soup.body.h1)
# print(soup.html.body.h1)
#
# soup.find("tag")=soup.tag
# soup.find("tag",{"attr":"value"})=soup.find("tag",attr="value")
#
# # 找尋全部
# find_all()
#
# # 列印標籤全部內容
# print(soup.find("h1"))
# # 列印標籤內容
# print(soup.find("h1").text)
#
# # 找出第一個 td 的標籤
# print(soup.find("td"))
# # 找出第一個 td 的標籤並印出其文字內容
# print(soup.find("td").text)
# # 找出所有 td 的標籤
# print(soup.find_all("td"))
#
# # 不指定標籤，但找出所有屬性 class = "zzz" 的標籤
# print(soup.find_all("", {"class":"zzz"}))
#
# # 找出所有 td 標籤的第三個並找出其中的 a 標籤
# print(soup.find_all("td")[2].find("a"))
#
# # 非常實用的 for loop 寫法，當你使用 find_all 後，
# 想一口氣把 list 裡面所有 tags 的內容文字取出時，可以這樣寫
# [tag.text for tag in soup.find_all("tag")]
# ~~~

# %% [markdown]
# <a href="https://morvanzhou.github.io/tutorials/data-manipulation/scraping/2-02-beautifulsoup-css/">2.2 BeautifulSoup 解析网页: CSS (爬虫 scraping 基础教学/教程 Tutorial)</a>
#
# <a href="https://github.com/MorvanZhou/easy-scraping-tutorial/blob/master/notebook/2-2-beautifulsoup-css.ipynb">easy-scraping-tutorial/notebook/2-2-beautifulsoup-css.ipynb</a>

# %%
#爬取全部原始碼
from bs4 import BeautifulSoup
from urllib.request import urlopen

# if has Chinese, apply decode()
html = urlopen("https://morvanzhou.github.io/static/scraping/list.html").read().decode('utf-8')
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="cn">
# <head>
# 	<meta charset="UTF-8">
# 	<title>爬虫练习 列表 class | 莫烦 Python</title>
# 	<style>
# 	.jan {
# 		background-color: yellow;
# 	}
# 	.feb {
# 		font-size: 25px;
# 	}
# 	.month {
# 		color: red;
# 	}
# 	</style>
# </head>
#
# <body>
#
# <h1>列表 爬虫练习</h1>
#
# <p>这是一个在 <a href="https://morvanzhou.github.io/" >莫烦 Python</a> 的 <a href="https://morvanzhou.github.io/tutorials/data-manipulation/scraping/" >爬虫教程</a>
# 	里无敌简单的网页, 所有的 code 让你一目了然, 清晰无比.</p>
#
# <ul>
# 	<li class="month">一月</li>
# 	<ul class="jan">
# 		<li>一月一号</li>
# 		<li>一月二号</li>
# 		<li>一月三号</li>
# 	</ul>
# 	<li class="feb month">二月</li>
# 	<li class="month">三月</li>
# 	<li class="month">四月</li>
# 	<li class="month">五月</li>
# </ul>
#
# </body>
# </html>

# %%
#爬取所需資料(div,li:)

soup = BeautifulSoup(html, features='lxml')

# use class to narrow search
month = soup.find_all('li', {"class": "month"})
for m in month:
    print(m.get_text())
# Out:
# 一月
# 二月
# 三月
# 四月
# 五月

# %%
#人力銀行資料
from bs4 import BeautifulSoup
from urllib.request import urlopen

# if has Chinese, apply decode()
html = urlopen("file:///E:/brother/resume/1My104.html").read().decode('utf-8')
print(html)
"""
#全部表格資料
soup = BeautifulSoup(html, features='lxml')
# use class to narrow search
month = soup.find_all('div', {"class": "content"})
for m in month:
    print(m.get_text())

#部分資料
soup = BeautifulSoup(html, features='lxml')
# use class to narrow search
month = soup.find_all('div', {"class": "jobname_5"})
for m in month:
    print(m.get_text())

#所需資料
soup = BeautifulSoup(html, features='lxml')
# use class to narrow search
month = soup.find_all('div', {"class": "compname_5"})
for m in month:
    print(m.get_text())
"""
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <head>
#     <meta http-equiv="Content-Language"content="zh-tw">
# 	<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <script type="text/javascript" src="https://static.104.com.tw/104main/assets/jquery.min.js"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# var staticUrl = 'https://static.104.com.tw/104main';
# var baseUrl="";
# /*]]>*/
# </script>
# <title>My104會員中心 - 工作 - 應徵記錄</title>
#     <link rel="shortcut icon" href="https://www.104.com.tw/favicon.ico">
#     <link rel="stylesheet" type="text/css" href="https://static.104.com.tw/104main/pda/css/reset.css?v=20130726">
# 	<link rel="stylesheet" type="text/css" href="https://static.104.com.tw/104main/pda/css/my104.css?v=20170504">
# 	<link rel="stylesheet" type="text/css" href="https://static.104.com.tw/104main/pda/css/category_org.css?v=20141124">
#     <link rel="stylesheet" type="text/css" href="https://static.104.com.tw/104main/pda/css/e104_selecteditem.css?v=20130726">
#     <link rel="stylesheet" type="text/css" href="https://www.104.com.tw/css/AutoSuggest.css?v=20160622" />
#     <script type="text/javascript" src="https://static.104.com.tw/104main/pda/js/cookie_comp.js?v=20180427" crossorigin="anonymous"></script>
# 	<!--[if IE 7]><link href="https://static.104.com.tw/104main/pda/css/my104_ie7.css?v=20130911" rel="stylesheet" type="text/css" /><![endif]-->
#     <!--[if lte IE 6]><link href="https://static.104.com.tw/104main/pda/css/my104_ie6.css?v=20130726" rel="stylesheet" type="text/css" /><![endif]-->
#     <!-- <script type="text/javascript" src="https://static.104.com.tw/104main/pda/js/rollbar.js?v=20180427&env=PROD" crossorigin="anonymous"></script> -->
#     <script type="text/javascript" src="https://static.104.com.tw/104main/pda/js/my104ajax.js?v=20180427"></script>
#     <script type="text/javascript" language="javascript" src="https://static.104.com.tw/bubble/js/mainjs.js?by=mybar&v=20180305"></script>
#
# 	<!-- Google Adwords -->
#     <!-- Global site tag (gtag.js) - Google AdWords: 992115811 -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=AW-992115811"></script>
#     <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'AW-992115811');
#     </script>
#     <!-- End Google Adwords -->
#
# </head>
# <body>
# <div id="globalbar"><div id="bar_m104"><div id="global_bk"></div></div></div><script type="text/javascript" src="https://static.104.com.tw/104main/common/browser.2.0.min.js?v=20130726"></script>
#
# <script>
#
# 	if(getCookie('chkIeStatus') != 'incompatible'){
# 		commonBrowser104.init({
# 		  date: '2018/4/1', // 必填 - 到期日文案
# 		  browserVersion: 'IE10', // 必填 - 支援度文案
# 		  lowest: ['10'], // 必填 - 最低支援版本號(Array格式)
# 		  support: ['ie'], // 必填 - 要偵測的瀏覽器(Array格式)
# 		  fixedHeight: '10px', // 選填 - 要fixed的高度
# 		  appendId: 'browserId' // 選填 - 要提示顯示插入到id裡(default: body最上面)
# 		});
# 	}
#
# 		$('#bsOverlay').live('click', function() {
# 			var expires = new Date();
# 			expires.setDate(expires.getDate()+1);
# 			setCookie('chkIeStatus','incompatible',expires);
# 		});
#
# </script>
# <div id="wrapper">
#
#     <div id="header">        <div id="my_ad_top">
#             <div id="aidma_570"><a href="javascript:void(0);"></a></div>
#         </div>
# <a href="/my104/center/index?u=pjlxwu"><span class="logo"></span></a></div>
#
#     <div id="nav">
#         <div id="nav_search">
#             <div class="nav_search_form">
#                 <div class="search_menu home_search">找工作</div>
#                 <div id="home_job_com" class="sortlist_menu">
#                     <p><a href="javascript:void(0);">找公司</a></p>
#                 </div>
#                 <input id="keyword_search" name="keyword_search" type="text" class="menu_search" autocomplete="off"/>
#                 <input id="keyword_type" name="keyword_type" type="hidden" class="menu_search_hidden" value="findJob"/>
#                 <input id="keyword_btn" type="button" class="btn_search"/>
#             </div>
#         </div>
#         <div id="nav_menu">
#             <ul id="navlist">
#                 <li class="home ">
#                     <a class="home" href="/my104/center/index?u=pjlxwu">首頁</a>
#                 </li>
#                 <li class="resume ">
#                     <a class="resume" href="/my104/resume/manage/index?u=pjlxwu">履歷</a>
#                     <div class="submenu">
#                         <div class="submenu-grid">
#                             <div class="submenu-content clearfix">
#                                 <div class="submenu-col w150" id="megamenu_resume">
#                                     <ul class="nav_sub">
#                                                                                 <li id="mResumeList"><a href="/my104/resume/manage/index?u=pjlxwu">履歷總覽</a><span class="txt_gray">(1份)</span></li>
#
#                                                                                     <li id="mIndex_y21474c4t2b434d4749454w224w2" class="nav_rname">．<a href="/my104/resume/profile/index?nv=y21474c4t2b434d4749454w224w2&u=pjlxwu">履歷表</a></li>
#                                                                                 <li id="resume_new_href"><a href="javascript:void(0);" class="resume_new_btn">新增履歷</a></li>
#                                     </ul>
#                                 </div>
#                                 <div class="submenu-col w100 bd_r_0">
#                                     <ul class="nav_sub">
#                                                                             <li>
#                                             <a href="/my104/resume/manage/set?nv=y21474c4t2b434d4749454w224w2&u=pjlxwu" class="resumeSet">履歷開放設定</a>
#                                             <input type="hidden" id="open_trigger" class="">
#                                         </li>
#                                         <li><a href="/my104/resume/applymsg/index?u=pjlxwu">自我推薦信</a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                 </li>
#                 <li class="job jobactive">
#                     <a class="job" href="/my104/mate/index?u=pjlxwu">工作</a>
#                     <div class="submenu">
#                         <div class="submenu-grid">
#                             <div class="submenu-content clearfix">
#                                 <div class="submenu-col w100">
#                                     <ul class="nav_sub">
#                                         <li><a href="/my104/mate/index?u=pjlxwu">配對條件總覽</a></li>
#                                         <li><a href="/my104/jobStore/index?u=pjlxwu">儲存工作</a></li>
#                                         <li><a href="/my104/companyStore/index?u=pjlxwu">儲存公司</a></li>
#                                     </ul>
#                                 </div>
#
#                                 <div class="submenu-col w100 bd_r_0">
#                                     <ul class="nav_sub">
#                                         <li><a href="/my104/applyRecord/index?u=pjlxwu">應徵紀錄</a></li>
#                                         <li><a href="/my104/interview/index?u=pjlxwu">通知我的公司</a></li>
#                                                                                         <li><a href="/my104/peruseRecord/index?u=pjlxwu">看過我的公司</a></li>
#
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                 </li>
#                 <li class="tool ">
#                     <a class="tool" href="/my104/exam/index?u=pjlxwu">工具</a>
#                     <div class="submenu">
#                         <div class="submenu-grid">
#                             <div class="submenu-content clearfix">
#                                 <div class="submenu-col w120">
#                                     <h3>事前準備</h3>
#                                     <ul class="nav_sub">
#                                         <li><a href="/my104/exam/freetest?u=pjlxwu">104職業適性測驗</a></li>
#                                                                                     <li><a href="/my104/exam/interestExam">職涯興趣量表</a></li>
#                                             <li><a href="/my104/exam/valueExam">工作價值觀量表</a></li>
#                                                                             </ul>
#                                 </div>
#                                 <div class="submenu-col w120">
#                                     <h3>新鮮人</h3>
#                                     <ul class="nav_sub">
#                                         <li><a href="https://www.104.com.tw/jb/career/department/redirect?degree=3&sName=%E5%9C%8B%E7%AB%8B%E8%99%8E%E5%B0%BE%E7%A7%91%E6%8A%80%E5%A4%A7%E5%AD%B8&dName=%E5%8B%95%E5%8A%9B%E6%A9%9F%E6%A2%B0%E7%B3%BB&i_from=my104" target="_blank" id="departUrl">升學就業地圖<span class="icon_survey"></span></a></li>
#                                         <li><a href="/my104/fresh/degree?u=pjlxwu">用學歷找</a></li>
#                                     </ul>
#                                 </div>
#                                 <div class="submenu-col w120">
#                                     <h3>上班族</h3>
#                                     <ul class="nav_sub">
#                                         <li><a href="/my104/office/experience?u=pjlxwu">用工作經驗找</a></li>
#                                     </ul>
#                                 </div>
#                                 <div class="submenu-col w100 bd_r_0">
#                                     <h3>輔助資訊</h3>
#                                     <ul class="nav_sub">
#                                         <li><a href="/my104/assist/analysislist?u=pjlxwu">職務總覽</a></li>
#                                         <li><a href="/my104/assist/tipslist?u=pjlxwu">求職錦囊</a></li>
#                                         <li><a href="http://www.104.com.tw/jb/104i/JobWage/view?wf=my104" target="_blank">薪資情報<span class="icon_survey"></span></a></li>
#                                         <li><a href="https://www.104.com.tw/area/104safety/index.cfm" target="_blank">求職安全<span class="icon_survey"></span></a></li>
#                                         <li><a href="https://certify.104.com.tw" target="_blank">證照中心<span class="icon_survey"></span></a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                 </li>
#                 <li class="account ">
#                     <a class="account" href="https://accounts.104.com.tw/hello?t=setting" target = "_blank">設定</a>
#                     <div class="submenu">
#                         <div class="submenu-grid w120">
#                             <div class="submenu-content clearfix">
#                                 <div class="submenu-col bd_r_0">
#                                     <ul class="nav_sub">
#                                         <li><a href="https://accounts.104.com.tw/hello?t=setting" target = "_blank">修改密碼</a></li>
#                                         <li><a href="https://accounts.104.com.tw/hello?t=profile" target = "_blank">修改基本資料</a></li>
#                                         <li><a href="/my104/member/epaper?u=pjlxwu">訂閱電子報</a></li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                 </li>
#             </ul>
#         </div>
#     </div>
#
# <div id="box_new_resume" class="popup">
#         <form id="newresume-form" action="/my104/resume/manage/add" method="post">
#         <a href="javascript:void(0);" class="close"><span class="icon_close_b"></span></a>
#         <h2>新增履歷</h2>
#
#         <input type="hidden" value="1" name="nowRsmCnt" id="nowRsmCnt" />
#         <dl>
#                 <dt>履歷名稱：
#                 <input class="w200 empty" name="NewResumeFmo[resumeName]" id="NewResumeFmo_resumeName" type="text" maxlength="20" /><span class="error" id="NewResumeFmo_resumeName_em_" style="display:none"></span>                </dt>
#                 <dt><div class="txt_gray help_txt">此名稱可自行命名，方便您管理多份履歷，公司不會看到。</div></dt>
#                 <dt>
#                 <label for="NewResumeFmo_labelAddMethod">新增方式</label>：<span class="error" id="newResumeModel_resumeType_em_" style="display:none"></span></dt>
#                 <span  id='newResumeModel_resumeType'>
#                                 <dd style="display:;"><label class="copy_resume">複製履歷：</label>
#                     <ul class="form_list w360">
#
#
#                         <li class="radio"><input id="NewResumeFmo_resumeType_0" class="duplicate_resume" value="y21474c4t2b434d4749454w224w2" type="radio" name="NewResumeFmo[resumeType]" /><label for="NewResumeFmo_resumeType_0"> 履歷表</label></li>
#                     </ul>
#                 </dd>
#                 <dd><label class="copy_resume">空白履歷：</label>
#                      <ul class="form_list w360">
#                         <li class="radio"><input id="NewResumeFmo_resumeType_1" class="duplicate_resume" value="1" type="radio" name="NewResumeFmo[resumeType]" /><label for="NewResumeFmo_resumeType_1"> 一般履歷</label></li> <li class="radio"><input id="NewResumeFmo_resumeType_2" class="duplicate_resume" value="3" type="radio" name="NewResumeFmo[resumeType]" /><label for="NewResumeFmo_resumeType_2"> 高階履歷</label></li>
#                     </ul>
#                 </dd>
#                 </span>
#
#         </dl>
#         <div class="tip">
#             <ul>
#                 <li>一般履歷：用於應徵全職或兼職的職缺。</li>
#                 <li>高階履歷：用於應徵主管級職缺，僅提供104獵才顧問中心搜尋。</li>
#             </ul>
#         </div>
#
#         <ul class="function">
#             <li>
#                 <input id="decide_new_resume" name="decide_new" class="button yellow" type="submit" value=" 確定 " />            </li>
#             <li>
#                 <input id="cancel_new_resume" name="cancel_new" class="button gray" type="button" value=" 取消 " />            </li>
#         </ul>
#     </form></div>
#     <div class="path">
#     <div class="breadcrumbs">
# <a href="/">My104會員中心</a> > <a href="/my104/applyRecord/index?u=pjlxwu">工作</a></div>    </div>
#
#     <div class="box_h1"><h1 class="job">應徵記錄</h1></div>
# 	<div class="content">
#     <div id="box_104banner" class="box_banner">
#         <p class="explain_arrow"><a href="javascript:void(0);" class="close">說明<span class="icon_arrow_close" style='background-position: 0px -18px;'></span></a></p>
#         <div class="explain_banner banner_invite">
#             <p>
#                 各求才公司對收到履歷表後的處理方式與速度並不同，請耐心等候讀取確認。<a href="https://www.104.com.tw/jobbank/faq/index.cfm?m=9" target="_blank">說明>></a>
#                 <br>
#                 建議您，也可以主動詢問公司哦。
#             </p>
#             <span class='banner_bg_img'></span>
#         </div>
#     </div>
#
#         <ul class="function">
#         	<li class="button check"><input name="check_all" id="check_all" type="checkbox" value=""></li>
#             <li class="button"><input type="button" id="delete_record" value="刪除記錄" class="button gray"></li>
#             <li class="button_r">共<span class="numeral">55</span>筆</span></li>
#         </ul>
#
#         <div class="joblist_tit">
#             <ul>
#                 <li><div class="check">&nbsp;</div></li>
#                 <li><div class="storage_day"><a href="/my104/applyRecord/index?sort=0&u=pjlxwu"><span class="th_arrow on">▼</span>應徵<br>日期</a></div></li>
#                 <li><div class="jobname_5">職務名稱</div></li>
#                 <li><div class="compname_5">公司名稱</div></li>
#                 <li><div class="candidates">應徵<br>分析</div></li>
#                 <li><div class="candidates">履歷<br>快照</div></li>
#                 <li><div class="read">應徵<br>狀態</div></li>
#                 <li><div class="comp_receive">應徵回覆</div></li>
#             </ul>
#         </div>
#
# 									<div class="joblist_cont off">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97936568319642684"></div></li>
# 		                <li><div class="date txt_gray">11/26</div></li>
# 		                <li><div class="jobname_5 txt_gray">
# 		                				                			軟體工程師		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=384a446d5a463f2048423a1d1d1d1d5f2443a363189j56&amp;jobsource=pda_i" target="_blank" title="網際之星資訊股份有限公司">網際之星資訊股份有限公司</a></div></li>
# 		                <li><div class="candidates txt_gray">
# 										                			關閉
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z2846454t2d434a4c4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read txt_gray" title="求才公司已於 2018/11/27 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                										<a href="/my104/interview/detail?gb=53a4a484136474&reply=1&u=pjlxwu" target="_blank">11/26已回覆</a>
# 		                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97936568319632447"></div></li>
# 		                <li><div class="date ">11/26</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=54f6m&amp;jobsource=pda_i" target="_blank" title="軟體工程師">軟體工程師</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=434149723b3d456e3739416a3f453d2083030302f47635b7119j51&amp;jobsource=pda_i" target="_blank" title="高誠網路服務股份有限公司">高誠網路服務股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=50424a2e627451725a60422838363e67540424a733c3e466f444a42252525256a74e42463907j48&jobsource=pda_i" target="_blank">
# 										<span class="electrical_02" title="兩週內應徵人數6-10人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z2846454t2a44464c4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/26 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                										<a href="/my104/interview/detail?gb=43746484w2e454&reply=1&u=pjlxwu" target="_blank">12/05已回覆</a>
# 		                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97936568319629500"></div></li>
# 		                <li><div class="date ">11/26</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=6aqj6&amp;jobsource=pda_i" target="_blank" title="C/C++ Programmer(高雄)">C/C++ Programmer(高雄)</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=5a4a44283c6c3e6a40323c1d1d1d1d5f2443a363189j97&amp;jobsource=pda_i" target="_blank" title="台眾電腦股份有限公司">台眾電腦股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=66784b2d3c4e465e393a426b56464024248784a764c3e48292929292641363a2d008j54&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z2846454t29444a4e4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="系統已於 2018/11/26 將您的履歷送出">已送出		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97936568319621294"></div></li>
# 		                <li><div class="date ">11/26</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=3jlpz&amp;jobsource=pda_i" target="_blank" title="JAVA程式設計師(高雄)">JAVA程式設計師(高雄)</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=444a4424566c3f6a38423a1d1d1d1d5f2443a363189j52&amp;jobsource=pda_i" target="_blank" title="康大資訊股份有限公司">康大資訊股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=4f77492c654d465d3839416a3f453f1f261774a75434d4528282828253f682d2c917j02&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z2846454t264345494');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/26 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97936568319620757"></div></li>
# 		                <li><div class="date ">11/26</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=6drzy&amp;jobsource=pda_i" target="_blank" title="[第三事業處] Java 開發工程師 (工作地點:高雄)">[第三事業處] Java 開發工程師 (工作地點:高雄)</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=3b4d456e3739416a33353d663b41391c92c2c2c2a4549492654j98&amp;jobsource=pda_i" target="_blank" title="昊聲訊息技術有限公司">昊聲訊息技術有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=4070436b386c492344423c1f2c3e365f2383a426b34363e673c423a1d1d1d1d5f2454a3a6b88j48&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z284644423f4a4b4d4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/26 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                										<a href="/my104/interview/detail?gb=x214d464t2b44454&reply=1&u=pjlxwu" target="_blank">11/28已回覆</a>
# 		                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont off">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97936568319619905"></div></li>
# 		                <li><div class="date txt_gray">11/26</div></li>
# 		                <li><div class="jobname_5 txt_gray">
# 		                				                			軟體工程師 (Java)		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=5e3e466f383a426b34363e673c423a1d02d2d2d71464a4a2644j01&amp;jobsource=pda_i" target="_blank" title="意藍資訊股份有限公司">意藍資訊股份有限公司</a></div></li>
# 		                <li><div class="candidates txt_gray">
# 										                			關閉
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z284644423f4747494');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read txt_gray" title="求才公司已於 2018/11/26 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                										<a href="/my104/interview/detail?gb=4314b4c403b494&reply=1&u=pjlxwu" target="_blank">12/07已回覆</a>
# 		                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97936568319616594"></div></li>
# 		                <li><div class="date ">11/26</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=5yhbs&amp;jobsource=pda_i" target="_blank" title="APP開發工程師">APP開發工程師</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=564048713a3c446d363840693e443c1f22f2f2f2a4772502624j54&amp;jobsource=pda_i" target="_blank" title="旭峻資訊有限公司">旭峻資訊有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=383a426b386c492048683b1c442e365f2383a426b34363e673c423a1d1d1d1d1a7463a466b88j56&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z284644423e43484f4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/26 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97936568319611874"></div></li>
# 		                <li><div class="date ">11/26</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=6e5v6&amp;jobsource=pda_i" target="_blank" title="Python Developer(高雄)">Python Developer(高雄)</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=5e60436e4c6c3e683c423a1d1d1d1d5f2443a363189j01&amp;jobsource=pda_i" target="_blank" title="台灣新蛋股份有限公司">台灣新蛋股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=66784a2f3c4e465e393a426b5a5c3f6a758784a74484e46292929292442363a2d008j54&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z284644423c434d4c4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/26 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97481020627872937"></div></li>
# 		                <li><div class="date ">11/17</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=4e024&amp;jobsource=pda_i" target="_blank" title="Ogloba - Java 軟體工程師">Ogloba - Java 軟體工程師</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=3c70436e38363f2230683b1d1d1d1d5f2443a363189j99&amp;jobsource=pda_i" target="_blank" title="金永立有限公司">金永立有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=6050482d4672455c37384069366a3d6864240492c3a7245272727276b3f312c2b826j48&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z274e4d413c48454f4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/17 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97481020627865761"></div></li>
# 		                <li><div class="date ">11/17</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=4b9hd&amp;jobsource=pda_i" target="_blank" title="Java程式設計師(台北)">Java程式設計師(台北)</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=624a42243c5c3f2330683b1d1d1d1d5f2443a363189j50&amp;jobsource=pda_i" target="_blank" title="中鋼集團_網際優勢股份有限公司">中鋼集團_網際優勢股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=637143253d6d405732333b64573f3719741614428356d40222222221f3b3c2726472j51&jobsource=pda_i" target="_blank">
# 										<span class="electrical_03" title="兩週內應徵人數11-30人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z274e4d413a444b4e4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/27 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97481020627864837"></div></li>
# 		                <li><div class="date ">11/17</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=5ct49&amp;jobsource=pda_i" target="_blank" title="程式研發工程師">程式研發工程師</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=623a436e5a46402140323c1d1d1d1d5f2443a363189j50&amp;jobsource=pda_i" target="_blank" title="104人力銀行_一零四資訊科技股份有限公司">104人力銀行_一零四資訊科技股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=514b442a5f37415732333b64572f386315f4b452645374122222222213b3c2726472j49&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z274e4d41394b4a4a4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/20 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97481020627862410"></div></li>
# 		                <li><div class="date ">11/17</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=3d4rz&amp;jobsource=pda_i" target="_blank" title="高雄軟體園區 - 軟體工程師2">高雄軟體園區 - 軟體工程師2</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=624a43274c463f6838583a1d1d1d1d5f2443a363189j50&amp;jobsource=pda_i" target="_blank" title="精益科技股份有限公司">精益科技股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=4f4d45284f49425934353d6659413a1e1534d466f3f5f4124242424213c642928654j02&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z274e4d413943474e4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/19 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97481020627862180"></div></li>
# 		                <li><div class="date ">11/17</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=3n7rp&amp;jobsource=pda_i" target="_blank" title="Java軟體工程師(高雄)">Java軟體工程師(高雄)</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=3c4a436c565c3f2452583a1d1d1d1d5f2443a363189j99&amp;jobsource=pda_i" target="_blank" title="景佳科技有限公司">景佳科技有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=3d6547723d61445b36373f6835433c6535f65482d5b614326262626683e402b2a735j00&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z274e4d41384c484a4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/22 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97481020626427224"></div></li>
# 		                <li><div class="date ">11/14</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=6epyw&amp;jobsource=pda_i" target="_blank" title="高薪 年收70萬起 程式設計師 一年經驗可 ITS">高薪 年收70萬起 程式設計師 一年經驗可 ITS</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=4b39416a33353d662f313962373d351862828286d40355b6795j98&amp;jobsource=pda_i" target="_blank" title="全球人事顧問股份有限公司">全球人事顧問股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=5474476f3c704d6c5e363f6a44323a6313c3e466f383a426b40463e212121211c9494e462a47j52&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z274e494x2c484b4d4');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/14 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97481020626415519"></div></li>
# 		                <li><div class="date ">11/14</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=5n16d&amp;jobsource=pda_i" target="_blank" title="620_ C++ 工程師">620_ C++ 工程師</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=4870432734363e673c423b1d1d1d1d5f2443a363189j56&amp;jobsource=pda_i" target="_blank" title="神通資訊科技股份有限公司">神通資訊科技股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=5767492e4b4d475d3839416a436b3e2203f414972474d4628282828283f682d2c917j55&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z274e494x294a4c494');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/14 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97481020625694166"></div></li>
# 		                <li><div class="date ">11/13</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=6cxpn&amp;jobsource=pda_i" target="_blank" title="資料科學工程師">資料科學工程師</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=475149723b3d456e3739416a3f453d20830303074493d517119j55&amp;jobsource=pda_i" target="_blank" title="新視域科技股份有限公司">新視域科技股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=5f61446c396d4a6b49333d66353f37608393b436c35373f683d433b1e1e1e1e61945614b2a77j02&jobsource=pda_i" target="_blank">
# 										<span class="electrical_03" title="兩週內應徵人數11-30人"></span>
# 									</a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 履歷快照 -->
# 		                	<div class="candidates">
# 		                				                			<a href="#" onclick="readResumeSnapshot('y2146444t2643454e4c474t274y2','z274e474v2c484b464');return false;"><span class="icon_view_resume" title="求才公司看到我的履歷表的內容"></span></a>
# 		                				                	</div>
# 		                </li>
# 		                <li>
# 		                	<div class="read " title="求才公司已於 2018/11/14 讀取您的履歷">已讀取		                	</div>
# 		                </li>
# 		                <li>
# 		                	<!-- 公司回覆狀態 -->
# 		                	<div class="comp_receive">
# 		                			                				                			                	</div>
# 		                </li>
# 		            </ul>
# 		        </div>
# 							<div class="joblist_cont ">
# 		            <ul>
# 		                <li><div class="check"><input name="check_delete" type="checkbox" value="97481020625687346"></div></li>
# 		                <li><div class="date ">11/13</div></li>
# 		                <li><div class="jobname_5 ">
# 		                				                			<a href="https://www.104.com.tw/job/?jobno=6372g&amp;jobsource=pda_i" target="_blank" title="AI演算法工程師(新北市)">AI演算法工程師(新北市)</a>
# 		                				                	</div>
# 		                </li>
# 		                <li><div class="compname_5"><a href="https://www.104.com.tw/jobbank/custjob/index.php?r=cust&amp;j=623a426b34363e6730323a63383e361972929296e405c4a6785j50&amp;jobsource=pda_i" target="_blank" title="智慧雲端科技股份有限公司">智慧雲端科技股份有限公司</a></div></li>
# 		                <li><div class="candidates ">
# 																	<a href="https://www.104.com.tw/jobs/apply/analysis?j=466648713e724f6d4e5e406c5c343c6533e4048713a3c446d424840232323232084c40442a27j54&jobsource=pda_i" target="_blank">
# 										<span class="electrical_01" title="兩週內應徵人數0-5人"></span>
# 									</a>
# 		                				                	</div>
# ...
# 				<P>
# 					<span class="numeral_12">職務：</span><span>資深後端工程師 Sr. Python Engineer</span>
# 					<span class="selectjob">精選</span>				</P>
# 				<P><span class="numeral_12">公司名稱：</span><span>創順科技有限公司</span></P>
# 				<P><span class="numeral_12">工作地點：</span><span>台北市內湖區</span></P>
# 				<P><span class="numeral_12">學歷：</span><span>大學</span></P>
# 				<P><span class="numeral_12">工作經驗：</span><span>3年</span></P>
# 				<P><span class="numeral_12">工作內容：</span></P>
# 				<P>
# 					<span>
# 						<ul>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# 									<li>4. 具備比較豐富的 Web 應用研發經驗，能夠熟練處理各種高並發複雜業務的實現。</li>
# 						  						</ul>
# 					</span>
# 				</P>
# 				<div class="arrow_bottom"></div>
# 	        </div>
# 						<div id="job_info5" class="popup job_suggest">
# 	            <div class="arrow_top"></div>
# 				<P>
# 					<span class="numeral_12">職務：</span><span>AI Engineer (人工智慧工程師)</span>
# 					<span class="selectjob">精選</span>				</P>
# 				<P><span class="numeral_12">公司名稱：</span><span>英屬開曼群島商盾心科技股份有限公司台灣分公司</span></P>
# 				<P><span class="numeral_12">工作地點：</span><span>台北市內湖區</span></P>
# 				<P><span class="numeral_12">學歷：</span><span>大學</span></P>
# 				<P><span class="numeral_12">工作經驗：</span><span>不拘</span></P>
# 				<P><span class="numeral_12">工作內容：</span></P>
# 				<P>
# 					<span>
# 						<ul>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# 									<li>This position is aligned with candidates who have a career plan toward an AI-Full Stack engineer. The selected candidate will have to read and implement scientific papers, devise production systems and take care of the services on production.</li>
# 						  						</ul>
# 					</span>
# 				</P>
# 				<div class="arrow_bottom"></div>
# 	        </div>
# 						<div id="job_info10735421" class="popup job_suggest">
# 	            <div class="arrow_top"></div>
# 				<P>
# 					<span class="numeral_12">職務：</span><span>工務人員</span>
# 									</P>
# 				<P><span class="numeral_12">公司名稱：</span><span>祥益金屬股份有限公司</span></P>
# 				<P><span class="numeral_12">工作地點：</span><span>高雄市苓雅區</span></P>
# 				<P><span class="numeral_12">學歷：</span><span>不拘</span></P>
# 				<P><span class="numeral_12">工作經驗：</span><span>1年</span></P>
# 				<P><span class="numeral_12">工作內容：</span></P>
# 				<P>
# 					<span>
# 						<ul>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# 									<li>5.能配合外派工地駐場出勤。</li>
# 						  						</ul>
# 					</span>
# 				</P>
# 				<div class="arrow_bottom"></div>
# 	        </div>
# 						<div id="job_info9946275" class="popup job_suggest">
# 	            <div class="arrow_top"></div>
# 				<P>
# 					<span class="numeral_12">職務：</span><span>軟體開發工程師</span>
# 									</P>
# 				<P><span class="numeral_12">公司名稱：</span><span>威捷生物醫學股份有限公司</span></P>
# 				<P><span class="numeral_12">工作地點：</span><span>高雄市鹽埕區</span></P>
# 				<P><span class="numeral_12">學歷：</span><span>大學、碩士</span></P>
# 				<P><span class="numeral_12">工作經驗：</span><span>1年</span></P>
# 				<P><span class="numeral_12">工作內容：</span></P>
# 				<P>
# 					<span>
# 						<ul>
#
# </li>
#
# </li>
#
# 									<li>3.影像處理相關程式設計</li>
# 						  						</ul>
# 					</span>
# 				</P>
# 				<div class="arrow_bottom"></div>
# 	        </div>
# 						<div id="job_info10837126" class="popup job_suggest">
# 	            <div class="arrow_top"></div>
# 				<P>
# 					<span class="numeral_12">職務：</span><span>Software Engineer (軟體工程師 網頁開發相關)-無經驗</span>
# 									</P>
# 				<P><span class="numeral_12">公司名稱：</span><span>亞家科技股份有限公司</span></P>
# 				<P><span class="numeral_12">工作地點：</span><span>高雄市三民區</span></P>
# 				<P><span class="numeral_12">學歷：</span><span>專科以上</span></P>
# 				<P><span class="numeral_12">工作經驗：</span><span>不拘</span></P>
# 				<P><span class="numeral_12">工作內容：</span></P>
# 				<P>
# 					<span>
# 						<ul>
#
# </li>
#
# </li>
#
# 									<li>3.與系統分析師及前端工程師合作完成專案</li>
# 						  						</ul>
# 					</span>
# 				</P>
# 				<div class="arrow_bottom"></div>
# 	        </div>
# 						<div id="job_info10801530" class="popup job_suggest">
# 	            <div class="arrow_top"></div>
# 				<P>
# 					<span class="numeral_12">職務：</span><span>Senior Software Engineer (資深軟體工程師 網頁開發相關)</span>
# 									</P>
# 				<P><span class="numeral_12">公司名稱：</span><span>亞家科技股份有限公司</span></P>
# 				<P><span class="numeral_12">工作地點：</span><span>高雄市三民區</span></P>
# 				<P><span class="numeral_12">學歷：</span><span>專科以上</span></P>
# 				<P><span class="numeral_12">工作經驗：</span><span>不拘</span></P>
# 				<P><span class="numeral_12">工作內容：</span></P>
# 				<P>
# 					<span>
# 						<ul>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# 									<li>五、定期舉辦新技術研討會</li>
# 						  						</ul>
# 					</span>
# 				</P>
# 				<div class="arrow_bottom"></div>
# 	        </div>
# 						<div id="job_info10825353" class="popup job_suggest">
# 	            <div class="arrow_top"></div>
# 				<P>
# 					<span class="numeral_12">職務：</span><span>4022- iSO產品開發程式設計師</span>
# 									</P>
# 				<P><span class="numeral_12">公司名稱：</span><span>遠綠資訊科技股份有限公司</span></P>
# 				<P><span class="numeral_12">工作地點：</span><span>高雄市前鎮區</span></P>
# 				<P><span class="numeral_12">學歷：</span><span>專科、大學、碩士</span></P>
# 				<P><span class="numeral_12">工作經驗：</span><span>1年</span></P>
# 				<P><span class="numeral_12">工作內容：</span></P>
# 				<P>
# 					<span>
# 						<ul>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# </li>
#
# 									<li>※ 此次本職缺招募之錄取者會即時通知求職結果，但須由公司另擇報到日期統一辦理所有錄取者的報到手續，歡迎可配合的求職者主動投遞履歷。</li>
# 						  						</ul>
# 					</span>
# 				</P>
# 				<div class="arrow_bottom"></div>
# 	        </div>
# 					</div>
#
# 	<!-- 主動應徵 -->
# 	<form name="apply_form" id="apply_form" action="" method="post">
# 		<input type="hidden" name="custno" id="custno" value="">
# 		<input type="hidden" name="jobno" id="jobno" value="">
# 		<input type="hidden" name="cookie_names" id="cookie_names" value="">
# 	</form>
#
# <script src="https://static.104.com.tw/104main/pda/js/my104/job/applyrecord/index.js?v=20180427" crossorigin="anonymous"></script>
#     <div id="footer">
#         <div id="pop_tel">
#         	<div class="pop_tel_bg">
# 	            <a href="#tel_box" id="close_pop_tel" class="close"><img src="https://static.104.com.tw/104main/pda/img/icon_close.gif"></a>
# 	            <div class="tel_job">
# 	                <dl>
# 	                    <dt>求職服務專線</dt>
# 	                    <dd>02-2912-6104 轉2</dd>
# 						<dd>02-7703-3104 轉2</dd>
# 	                    <dd>&nbsp;</dd>
# 	                    <dd><span class="icon_letter2">&nbsp;</span><a href="https://www.104.com.tw/question_admin/reaction.cfm" target="_blank">意見回饋</a></dd>
# 	                    <dd><span class="icon_safe">&nbsp;</span><a href="javascript:void(0)" onClick="window.open('http://www.104.com.tw/public/pda/pop_safety.htm','','scrollbars=yes,width=500,height=480')">職場安全諮詢專線</a></dd>
# 	                </dl>
# 	                <P>服務時間：週一至週五<span>9:00~19:00</span></P>
# 	            </div>
#             </div>
#             <div class="arrow_bottom"></div>
#         </div>
#
#         <P class="bg">
#             <a href="#tel_box" name="tel_box" id="open_pop_tel"><span class="tel_logo" title="聯絡客服">&nbsp;</span></a>
#             <span class="icon_safe">&nbsp;</span><a href="javascript:void(0)" onClick="window.open('http://www.104.com.tw/public/pda/pop_safety.htm','','scrollbars=yes,width=500,height=480')">職場安全諮詢專線</a>
#         </P>
#         <P>104人力銀行網站由一零四資訊科技股份有限公司創設。建議瀏覽器版本為IE11以上。</P>
#         <P>本網站內容享有著作權，禁止侵害，違者必究。 &copy; 2018 104 Corporation All Rights Reserved</P>
#     </div>
#
#
#
# </div>
# <!--  disable button hover 過顯示的 info -->
# <div id="disable_info" class="popup">
#     <div class="arrow_top"></div>
#     <p><span id="limit_txt"></span></p>
# </div>
# <div id="divorg"></div> <!-- 複選選單div -->
# <div id="lightbox"></div> <!-- lightbox -->
# 		<div id="box_resume_store_no" class="popup">
#             <a href="javascript:void(0);" class="close"><span class="icon_close_b"></span></a>
#             <h2>無履歷資料</h2>
#             <p>您目前無履歷資料，因此無法進行履歷設定。</p>
#             <ul class="function">
#                 <li><input id="decide_store_new" name="decide_store_new" type="button" class="button yellow" value="新增履歷"></li>
#                 <li><input id="cancel_store" name="cancel_store" type="button" class="button gray" value="暫不修改"></li>
#             </ul>
#         </div>
#
#
# 		<div id="box_resume_store_dnf" class="popup">
#             <a href="javascript:void(0);" class="close"><span class="icon_close_b"></span></a>
#             <h2>履歷未填寫完成</h2>
#             <p>您尚未填寫
#
#             ，因此目前無法進行履歷設定。</p>
#             <P>請先填寫完成，才可開放履歷給求才公司搜尋，並且使用應徵功能！</P>
#             <ul class="function">
#                 <li><input id="dnf_decide_store" name="dnf_decide_store" type="button" class="button yellow" value="修改履歷"></li>
#                 <li><input id="dnf_cancel_store" name="dnf_cancel_store" type="button" class="button gray" value="暫不修改"></li>
#             </ul>
#         </div>
#
# <script type="text/javascript">
# //alexa
# _atrk_opts = { atrk_acct:"lRlHh1awVK00wf", domain:"104.com.tw",dynamic: true};
# (function() {
# 	var as = document.createElement('script');
# 	 as.type = 'text/javascript';
# 	 as.async = true;
# 	 as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js";
# 	 var s = document.getElementsByTagName('script')[0];
# 	 s.parentNode.insertBefore(as, s);})();
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-THMR39"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-THMR39');</script>
# <!-- End Google Tag Manager -->
#
# <script src="https://static.104.com.tw/104main/pda/js/components/afupload/AFUpload.js?v=20180427" crossorigin="anonymous"></script>
# <script src="https://static.104.com.tw/104main/pda/js/common.js?v=20180427" crossorigin="anonymous"></script>
# <script src="https://static.104.com.tw/104main/js/jquery/jquery.defaultvalue.min.js?v=20180427" crossorigin="anonymous"></script>
# <script src="https://static.104.com.tw/104main/pda/js/main.js?v=20180427" crossorigin="anonymous"></script>
# <script src="https://www.104.com.tw/public/area/AutoSuggest/AutoSuggest.js?v=20180427"></script>
# <script src="https://static.104.com.tw/104main/pda/js/megamenu/keyword_search.js?v=20180427" crossorigin="anonymous"></script>
# <script src="https://static.104.com.tw/104main/pda/js/components/AjaxActiveForm.js?v=20180427" crossorigin="anonymous"></script>
#
# <script type="text/javascript">
#     $(window).load(function(){
#         var skey = "";
#         if (skey && $('.global_lr a:contains("登出")').length) {
#             $('.global_lr a:contains("登出")').on('click', function(event) {
#                 var w1 = window.open(skey, "_new");
#                 w1.blur();
#             });
#         }
#     });
# </script>
# <script type="text/javascript" src="https://static.104.com.tw/104main/pda/js/my104/tool/nccLog.js?v=20180427"></script>
# <script type="text/javascript" src="https://static.104.com.tw/104main/pda/js/my104/job/job.js?v=20180427"></script>
# <script type="text/javascript" src="https://static.104.com.tw/104main/pda/js/e104_lightbox.js?v=20180427"></script>
# <script type="text/javascript" src="https://aidma.104.com.tw/js/e104aidma.php?wid=2&amp;cid=18"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
#
# 				var delUrl = '/my104/applyRecord/delete?u=pjlxwu';
# 				var applyUrl = 'https://www.104.com.tw/jobs/apply/form';
# 				var loginUrl = 'https://www.104.com.tw/jobs/search/showLogin';
#
# var extDevice='web'; if(typeof _elog != 'undefined'){ _elog.push({web:'104_bank',track:['exposureSelectJob','4143534,10614235,9025554,9561699,7600996'],ext:{'device':extDevice,'source':location.href,'jobno':'4143534,10614235,9025554,9561699,7600996'}}); _elog.push({web:'104_bank',track:['applyRecordList_plist','10735420,9946274,10837125,10801529,10825352'],ext:{'device':extDevice,'source':location.href,'jobno':'10735420,9946274,10837125,10801529,10825352'}});}
# var masterNv="y21474c4t2b434d4749454w224w2";
# var resumeLostCont="";
# var nowNv="";
# var hasCompleteResume=1;
# var resumeCount=1;
# var userStatus=1;
# jQuery(function($) {
# $('#newresume-form').AjaxActiveForm({'validateOnSubmit':true,'validateOnChange':false,'beforeValidate':newResumeBeforeValidate,'afterValidate':newResumeAfterValidate,'onSubmitSuccess':newResumeSuccessProccess,'onSubmitError':function(form, data, textStatus){newResumeErrorProcess(form, data, textStatus)},'hideErrorMessage':false,'attributes':[{'id':'NewResumeFmo_resumeName','inputID':'NewResumeFmo_resumeName','inputName':'NewResumeFmo[resumeName]','errorID':'NewResumeFmo_resumeName_em_','model':'NewResumeFmo','name':'resumeName','enableAjaxValidation':false,'clientValidation':function(value, messages, attribute) {
#
# if($.trim(value)!='') {
#
# if(value.length>20) {
# 	messages.push("<span class=\"icon_attention\"><\/span>\u5c65\u6b77\u540d\u7a31\u5b57\u6578\u904e\u9577");
# }
#
# }
#
# 			if(/[`|>|<|;|#|@|\!|\"|'|?|~|%|*|^|$|{|}|=|<|>|\\|‵|＜|＞|；|＃|＠|！|＂|？|～|％|＄|＊|︿|｛|｝|＝|＜|＞|＼]/.test($("#NewResumeFmo_resumeName").val()))
# 			{
#
# 				messages.push("<span class=\"icon_attention\"></span>請勿輸入特殊符號");
# 			}
# }},{'id':'NewResumeFmo_resumeType','inputID':'newResumeModel_resumeType','inputName':'NewResumeFmo[resumeType]','errorID':'newResumeModel_resumeType_em_','model':'NewResumeFmo','name':'resumeType','enableAjaxValidation':false,'clientValidation':function(value, messages, attribute) {
#
# if($.trim(value)=='') {
# 	messages.push("<span class=\"icon_attention\"><\/span>\u8acb\u9078\u64c7\u5c65\u6b77\u985e\u578b");
# }
#
# }}],'revert':function(){$('#newresume-form').find('[name="NewResumeFmo\[resumeType\]"]').each(function(){if($(this).val() == ""){$(this).prop('checked',true);}else{$(this).prop('checked',false);}});$('#NewResumeFmo_resumeName').val("");; var $form = $("#newresume-form");if($form.length > 0){var settings = $form.data('settings');if(typeof(settings.attributes)!='undefined'){$.each(settings.attributes, function () {try{$error = $form.find('#' + this.errorID);$error.toggle(false);}catch(e){}});}}		}});
# });
# /*]]>*/
# </script>
# </body>
#
# </html>
# '\n#全部表格資料\nsoup = BeautifulSoup(html, features=\'lxml\')\n# use class to narrow search\nmonth = soup.find_all(\'div\', {"class": "content"})\nfor m in month:\n    print(m.get_text())\n\n#部分資料\nsoup = BeautifulSoup(html, features=\'lxml\')\n# use class to narrow search\nmonth = soup.find_all(\'div\', {"class": "jobname_5"})\nfor m in month:\n    print(m.get_text())\n\n#所需資料\nsoup = BeautifulSoup(html, features=\'lxml\')\n# use class to narrow search\nmonth = soup.find_all(\'div\', {"class": "compname_5"})\nfor m in month:\n    print(m.get_text())\n'
